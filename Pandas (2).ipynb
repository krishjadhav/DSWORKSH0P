# %%
import pandas as pd
import numpy as np

# %%
from numpy.random import randn
np.random.seed(101)

# %%
df = pd.DataFrame(randn(20,5),columns='W X Y Z A'.split())

# %%
df.head()
# Out:
#           W         X         Y         Z         A
# 0  2.706850  0.628133  0.907969  0.503826  0.651118
# 1 -0.319318 -0.848077  0.605965 -2.018168  0.740122
# 2  0.528813 -0.589001  0.188695 -0.758872 -0.933237
# 3  0.955057  0.190794  1.978757  2.605967  0.683509
# 4  0.302665  1.693723 -1.706086 -1.159119 -0.134841

# %%
df.head(2)
# Out:
#           W         X         Y         Z         A
# 0  2.706850  0.628133  0.907969  0.503826  0.651118
# 1 -0.319318 -0.848077  0.605965 -2.018168  0.740122

# %%
df.tail()
# Out:
#            W         X         Y         Z         A
# 15 -2.141212  0.992573  1.192241 -1.046780  1.292765
# 16 -1.467514 -0.494095 -0.162535  0.485809  0.392489
# 17  0.221491 -0.855196  1.541990  0.666319 -0.538235
# 18 -0.568581  1.407338  0.641806 -0.905100 -0.391157
# 19  1.028293 -1.972605 -0.866885  0.720788 -1.223082

# %%
df.tail(5)
# Out:
#            W         X         Y         Z         A
# 15 -2.141212  0.992573  1.192241 -1.046780  1.292765
# 16 -1.467514 -0.494095 -0.162535  0.485809  0.392489
# 17  0.221491 -0.855196  1.541990  0.666319 -0.538235
# 18 -0.568581  1.407338  0.641806 -0.905100 -0.391157
# 19  1.028293 -1.972605 -0.866885  0.720788 -1.223082

# %%
df.columns
# Out:
# Index(['W', 'X', 'Y', 'Z', 'A'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
df.shape
# Out:
# (20, 5)

# %%
df.info(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       20 non-null     float64
#  1   X       20 non-null     float64
#  2   Y       20 non-null     float64
#  3   Z       20 non-null     float64
#  4   A       20 non-null     float64
# dtypes: float64(5)
# memory usage: 928.0 bytes

# %%
df.describe()
# Out:
#                W          X          Y          Z          A
# count  20.000000  20.000000  20.000000  20.000000  20.000000
# mean    0.174426   0.037315   0.380732   0.031801   0.207575
# std     1.050186   0.979224   1.148564   1.188306   0.863311
# min    -2.141212  -1.972605  -1.706086  -2.018168  -1.223082
# 25%    -0.381634  -0.624962  -0.406665  -0.930122  -0.556241
# 50%     0.344348  -0.031370   0.397330   0.115351   0.475629
# 75%     0.717854   0.404268   1.279678   0.679936   0.697662
# max     2.706850   2.084019   1.978757   2.605967   1.996652

# %%
df = pd.DataFrame(randn(10,4),index='A B C D E F G H I J'.split(),columns='W X Y Z'.split())
df.head()
# Out:
#           W         X         Y         Z
# A  0.327845  0.674485 -0.174057  0.780140
# B -0.383258 -0.409318  0.343539  0.196275
# C -0.982776  2.231555 -0.971393 -1.522333
# D  1.133703  0.528187  0.393461 -0.630507
# E -1.398290 -0.219311 -0.045676  0.012421

# %% [markdown]
# ## Selection and Indexing

# %%
df['W']
# Out:
# A    1.606780
# B    0.041460
# C   -0.804652
# D   -1.080471
# E    0.975720
# F    0.586847
# G   -1.678284
# H    0.197524
# I    0.305632
# J   -0.251897
# Name: W, dtype: float64

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
# Pass a list of column names
df[['W','Z']]
# Out:
#           W         Z
# A  0.327845  0.780140
# B -0.383258  0.196275
# C -0.982776 -1.522333
# D  1.133703 -0.630507
# E -1.398290  0.012421
# F  0.093628 -1.908009
# G -0.380104  1.522562
# H  0.178009  1.743477
# I  1.130018 -1.063049
# J -0.125381 -1.046358

# %%
type(df[['W', 'Z']])
# Out:
# pandas.core.frame.DataFrame

# %%
# SQL Syntax (NOT RECOMMENDED!)
df.W
# Out:
# A    1.606780
# B    0.041460
# C   -0.804652
# D   -1.080471
# E    0.975720
# F    0.586847
# G   -1.678284
# H    0.197524
# I    0.305632
# J   -0.251897
# Name: W, dtype: float64

# %% [markdown]
# **Creating a new column:**

# %%
df['new'] = df['W'] + df['Y'] # can perform any arithmatic operation
df.head()
# Out:
#           W         X         Y         Z       new
# A  1.606780 -1.115710 -1.385379 -1.329660  0.221401
# B  0.041460 -0.411055 -0.771329  0.110477 -0.729869
# C -0.804652  0.253548  0.649148  0.358941 -0.155504
# D -1.080471  0.902398  0.161781  0.833029 -0.918690
# E  0.975720 -0.388239  0.783316 -0.708954  1.759036

# %%
df['new2'] = df['W']**2 + df['Y'] + df['W'] + df['X'] # can perform any arithmatic operation
df.head()
# Out:
#           W         X         Y         Z       new      new2
# A  1.606780 -1.115710 -1.385379 -1.329660  0.221401  1.687433
# B  0.041460 -0.411055 -0.771329  0.110477 -0.729869 -1.139205
# C -0.804652  0.253548  0.649148  0.358941 -0.155504  0.745508
# D -1.080471  0.902398  0.161781  0.833029 -0.918690  1.151126
# E  0.975720 -0.388239  0.783316 -0.708954  1.759036  2.322826

# %%
df['new3'] = 1 # can perform any arithmatic operation
df.head()
# Out:
#           W         X         Y         Z       new      new2  new3
# A  1.606780 -1.115710 -1.385379 -1.329660  0.221401  1.687433     1
# B  0.041460 -0.411055 -0.771329  0.110477 -0.729869 -1.139205     1
# C -0.804652  0.253548  0.649148  0.358941 -0.155504  0.745508     1
# D -1.080471  0.902398  0.161781  0.833029 -0.918690  1.151126     1
# E  0.975720 -0.388239  0.783316 -0.708954  1.759036  2.322826     1

# %%
df['new3'].unique()
# Out:
# array([1])

# %%
df['new3'].nunique()
# Out:
# 1

# %%
df['W'].max()
# Out:
# 1.606779861236061

# %%
df['W'].mean()
# Out:
# -0.01013413064739832

# %%
df['W'].median()
# Out:
# 0.11949196431577849

# %% [markdown]
# ** Removing Columns**

# %%
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z      new2  new3
# A  1.606780 -1.115710 -1.385379 -1.329660  1.687433     1
# B  0.041460 -0.411055 -0.771329  0.110477 -1.139205     1
# C -0.804652  0.253548  0.649148  0.358941  0.745508     1
# D -1.080471  0.902398  0.161781  0.833029  1.151126     1
# E  0.975720 -0.388239  0.783316 -0.708954  2.322826     1
# F  0.586847 -1.621348  0.677535  0.026105 -0.012576     1
# G -1.678284  0.333973 -0.532471  2.117727  0.939855     1
# H  0.197524  2.302987  0.729024 -0.863091  3.268551     1
# I  0.305632  0.243178  0.864165 -1.560931  1.506385     1
# J -0.251897 -0.578120  0.236996  0.200780 -0.529570     1

# %%
df
# Out:
#           W         X         Y         Z       new      new2  new3
# A  1.606780 -1.115710 -1.385379 -1.329660  0.221401  1.687433     1
# B  0.041460 -0.411055 -0.771329  0.110477 -0.729869 -1.139205     1
# C -0.804652  0.253548  0.649148  0.358941 -0.155504  0.745508     1
# D -1.080471  0.902398  0.161781  0.833029 -0.918690  1.151126     1
# E  0.975720 -0.388239  0.783316 -0.708954  1.759036  2.322826     1
# F  0.586847 -1.621348  0.677535  0.026105  1.264382 -0.012576     1
# G -1.678284  0.333973 -0.532471  2.117727 -2.210754  0.939855     1
# H  0.197524  2.302987  0.729024 -0.863091  0.926548  3.268551     1
# I  0.305632  0.243178  0.864165 -1.560931  1.169796  1.506385     1
# J -0.251897 -0.578120  0.236996  0.200780 -0.014901 -0.529570     1

# %%
df = df.drop('new',axis=1) # Axis 0 means rows, axis 1 means columns
df
# Out:
#           W         X         Y         Z      new2  new3
# A  1.606780 -1.115710 -1.385379 -1.329660  1.687433     1
# B  0.041460 -0.411055 -0.771329  0.110477 -1.139205     1
# C -0.804652  0.253548  0.649148  0.358941  0.745508     1
# D -1.080471  0.902398  0.161781  0.833029  1.151126     1
# E  0.975720 -0.388239  0.783316 -0.708954  2.322826     1
# F  0.586847 -1.621348  0.677535  0.026105 -0.012576     1
# G -1.678284  0.333973 -0.532471  2.117727  0.939855     1
# H  0.197524  2.302987  0.729024 -0.863091  3.268551     1
# I  0.305632  0.243178  0.864165 -1.560931  1.506385     1
# J -0.251897 -0.578120  0.236996  0.200780 -0.529570     1

# %%
df = df.drop(['new2','new3'],axis=1)
df
# Out:
#           W         X         Y         Z
# A  1.606780 -1.115710 -1.385379 -1.329660
# B  0.041460 -0.411055 -0.771329  0.110477
# C -0.804652  0.253548  0.649148  0.358941
# D -1.080471  0.902398  0.161781  0.833029
# E  0.975720 -0.388239  0.783316 -0.708954
# F  0.586847 -1.621348  0.677535  0.026105
# G -1.678284  0.333973 -0.532471  2.117727
# H  0.197524  2.302987  0.729024 -0.863091
# I  0.305632  0.243178  0.864165 -1.560931
# J -0.251897 -0.578120  0.236996  0.200780

# %%
# prompt: Using dataframe df: find E

# Assuming 'E' refers to a column named 'E' in the dataframe.
# If 'E' is something else, please clarify.

# Check if column 'E' exists in the dataframe.
if 'E' in df.columns:
    # If the column exists, perform the desired operation.
    # Example: Display the values in column 'E'
    print(df['E'])
else:
    # Handle the case where column 'E' is not found.
    print("Column 'E' not found in the DataFrame.")
# Out:
# Column 'E' not found in the DataFrame.

# %% [markdown]
# Can also drop rows this way:

# %%
df = df.drop('E',axis=0)
df
# Out:
#           W         X         Y         Z
# A  0.327845  0.674485 -0.174057  0.780140
# B -0.383258 -0.409318  0.343539  0.196275
# C -0.982776  2.231555 -0.971393 -1.522333
# D  1.133703  0.528187  0.393461 -0.630507
# F  0.093628  1.240813 -1.097693 -1.908009
# G -0.380104 -1.666059 -2.736995  1.522562
# H  0.178009 -0.626805 -0.391089  1.743477
# I  1.130018  0.897796  0.330866 -1.063049
# J -0.125381 -0.945588  2.029544 -1.046358

# %%
df = df.drop(['F','G','H','I','J','A'],axis=0)
df
# Out:
#           W         X         Y         Z
# B -0.383258 -0.409318  0.343539  0.196275
# C -0.982776  2.231555 -0.971393 -1.522333
# D  1.133703  0.528187  0.393461 -0.630507

# %% [markdown]
# ** Selecting Rows**

# %%
df
# Out:
#           W         X         Y         Z
# B -0.383258 -0.409318  0.343539  0.196275
# C -0.982776  2.231555 -0.971393 -1.522333
# D  1.133703  0.528187  0.393461 -0.630507

# %%
df.loc['A']
# Out:
# W    1.606780
# X   -1.115710
# Y   -1.385379
# Z   -1.329660
# Name: A, dtype: float64

# %%
df.loc[['A','B']]
# Out:
#          W         X         Y         Z
# A  1.60678 -1.115710 -1.385379 -1.329660
# B  0.04146 -0.411055 -0.771329  0.110477

# %% [markdown]
# Or select based off of position instead of label

# %%
df.iloc[1]
# Out:
# W   -0.982776
# X    2.231555
# Y   -0.971393
# Z   -1.522333
# Name: C, dtype: float64

# %%
df.iloc[2:5]
# Out:
#           W         X         Y         Z
# C -0.804652  0.253548  0.649148  0.358941
# D -1.080471  0.902398  0.161781  0.833029

# %%
df.iloc[1::2]
# Out:
#           W         X         Y         Z
# B  0.041460 -0.411055 -0.771329  0.110477
# D -1.080471  0.902398  0.161781  0.833029

# %% [markdown]
# ** Selecting subset of rows and columns **

# %%
df
# Out:
#           W         X         Y         Z
# A  1.606780 -1.115710 -1.385379 -1.329660
# B  0.041460 -0.411055 -0.771329  0.110477
# C -0.804652  0.253548  0.649148  0.358941
# D -1.080471  0.902398  0.161781  0.833029

# %%
df.loc['B','Y']
# Out:
# -0.7713286047373022

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#          W         Y
# A  1.60678 -1.385379
# B  0.04146 -0.771329

# %% [markdown]
# ### Conditional Selection
#
# An important feature of pandas is conditional selection using bracket notation, very similar to numpy:

# %%
df
# Out:
#           W         X         Y         Z
# A  1.606780 -1.115710 -1.385379 -1.329660
# B  0.041460 -0.411055 -0.771329  0.110477
# C -0.804652  0.253548  0.649148  0.358941
# D -1.080471  0.902398  0.161781  0.833029

# %%
df > 0
# Out:
#        W      X      Y      Z
# A   True  False  False  False
# B   True  False  False   True
# C  False   True   True   True
# D  False   True   True   True

# %%
df[df['W'] > 0]
# Out:
#          W         X         Y         Z
# A  1.60678 -1.115710 -1.385379 -1.329660
# B  0.04146 -0.411055 -0.771329  0.110477

# %%
df[df['W'] > 0]['Y']
# Out:
# A   -1.385379
# B   -0.771329
# Name: Y, dtype: float64

# %%
df[df['W'] > 0][['Y','X']]
# Out:
#           Y         X
# A -1.385379 -1.115710
# B -0.771329 -0.411055

# %% [markdown]
# For two conditions you can use | and & with parenthesis:

# %%
df
# Out:
#           W         X         Y         Z
# A  1.606780 -1.115710 -1.385379 -1.329660
# B  0.041460 -0.411055 -0.771329  0.110477
# C -0.804652  0.253548  0.649148  0.358941
# D -1.080471  0.902398  0.161781  0.833029

# %%
df[(df['W'] > 0) & (df['Y'] > 0)]
# Out:
# Empty DataFrame
# Columns: [W, X, Y, Z]
# Index: []

# %%
df[(df['W'] > 0) | (df['Y'] > 1)]
# Out:
#          W         X         Y         Z
# A  1.60678 -1.115710 -1.385379 -1.329660
# B  0.04146 -0.411055 -0.771329  0.110477

# %% [markdown]
# ## More Index Details
#
# Let's discuss some more features of indexing, including resetting the index or setting it something else. We'll also talk about index hierarchy!

# %%
df
# Out:
#           W         X         Y         Z
# A  1.606780 -1.115710 -1.385379 -1.329660
# B  0.041460 -0.411055 -0.771329  0.110477
# C -0.804652  0.253548  0.649148  0.358941
# D -1.080471  0.902398  0.161781  0.833029

# %%
# Reset to default 0,1...n index
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A  1.606780 -1.115710 -1.385379 -1.329660
# 1     B  0.041460 -0.411055 -0.771329  0.110477
# 2     C -0.804652  0.253548  0.649148  0.358941
# 3     D -1.080471  0.902398  0.161781  0.833029

# %%
newind = 'CA NY WY NY'.split()
newind
# Out:
# ['CA', 'NY', 'WY', 'NY']

# %%
df['States'] = newind

# %%
df
# Out:
#           W         X         Y         Z States
# A  1.606780 -1.115710 -1.385379 -1.329660     CA
# B  0.041460 -0.411055 -0.771329  0.110477     NY
# C -0.804652  0.253548  0.649148  0.358941     WY
# D -1.080471  0.902398  0.161781  0.833029     NY

# %%
df['States'].value_counts()
# Out:
# States
# NY    2
# CA    1
# WY    1
# Name: count, dtype: int64

# %%
df.set_index('States')
# Out:
#                W         X         Y         Z
# States
# CA      1.606780 -1.115710 -1.385379 -1.329660
# NY      0.041460 -0.411055 -0.771329  0.110477
# WY     -0.804652  0.253548  0.649148  0.358941
# NY     -1.080471  0.902398  0.161781  0.833029

# %%
df
# Out:
#           W         X         Y         Z States
# A  1.606780 -1.115710 -1.385379 -1.329660     CA
# B  0.041460 -0.411055 -0.771329  0.110477     NY
# C -0.804652  0.253548  0.649148  0.358941     WY
# D -1.080471  0.902398  0.161781  0.833029     NY

# %% [markdown]
# # Missing Data
#
# Let's show a few convenient methods to deal with Missing Data in pandas:

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'A':[1,2,np.nan],
                  'B':[5,np.nan,np.nan],
                  'C':[1,2,3]})

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.isna()
# Out:
#        A      B      C
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
df.isna().sum()
# Out:
# A    1
# B    2
# C    0
# dtype: int64

# %%
df.isna().mean()
# Out:
# A    0.333333
# B    0.666667
# C    0.000000
# dtype: float64

# %%
df
# Out:
#           W         X         Y         Z
# B -0.383258 -0.409318  0.343539  0.196275
# C -0.982776  2.231555 -0.971393 -1.522333
# D  1.133703  0.528187  0.393461 -0.630507

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna(thresh=2)
# Out:
#           W         X         Y         Z
# B -0.383258 -0.409318  0.343539  0.196275
# C -0.982776  2.231555 -0.971393 -1.522333
# D  1.133703  0.528187  0.393461 -0.630507

# %%
df.fillna(value='FILL VALUE')
# Out:
#           W         X         Y         Z
# B -0.383258 -0.409318  0.343539  0.196275
# C -0.982776  2.231555 -0.971393 -1.522333
# D  1.133703  0.528187  0.393461 -0.630507

# %%
df['A'].fillna(value=df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %% [markdown]
# # Groupby
#
# The groupby method allows you to group rows of data together and call aggregate functions

# %%
import pandas as pd
# Our data: dictionary of lists
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %% [markdown]
# ** Now you can use the .groupby() method to group rows together based off of a column name. For instance let's group based off of Company. This will create a DataFrameGroupBy object:**

# %%
df.groupby('Company')

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
by_comp = df.groupby("Company")['Sales'].mean()

print(by_comp)
# Out:
# Company
# FB      296.5
# GOOG    160.0
# MSFT    232.0
# Name: Sales, dtype: float64

# %%
by_comp = df.groupby("Company")['Sales'].sum()

print(by_comp)
# Out:
# Company
# FB      593
# GOOG    320
# MSFT    464
# Name: Sales, dtype: int64

# %%
by_comp = df.groupby("Company")['Sales'].max()

print(by_comp)
# Out:
# Company
# FB      350
# GOOG    200
# MSFT    340
# Name: Sales, dtype: int64

# %%
by_comp = df.groupby("Company")['Sales'].min()

print(by_comp)
# Out:
# Company
# FB      243
# GOOG    120
# MSFT    124
# Name: Sales, dtype: int64

# %% [markdown]
# ### Example DataFrames

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7])

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# ## Concatenation

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df1 = pd.DataFrame({
    'A': [7, 8, 9],
    'B': [4, 5, 6]
})

df2 = pd.DataFrame({
    'C': ['a', 'b', 'c'],
    'D': ['x', 'y', 'z']
})

# %%
df1
# Out:
#    A  B
# 0  7  4
# 1  8  5
# 2  9  6

# %%
df2
# Out:
#    C  D
# 0  a  x
# 1  b  y
# 2  c  z

# %%
pd.concat([df1, df2], axis=1)
# Out:
#    A  B  C  D
# 0  7  4  a  x
# 1  8  5  b  y
# 2  9  6  c  z

# %% [markdown]
# # Operations

# %%
import pandas as pd
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %% [markdown]
# ### Applying Functions

# %%
def times2(x):
    return x*2

df['col1'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df['col1'].apply(lambda x:x**2)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# Name: col1, dtype: int64

# %%
df['col3'].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %% [markdown]
# ** Sorting and Ordering a DataFrame:**

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
data = {
    'col1': [3, 1, 2, 3, 2],
    'col2': [5, 4, 3, 2, 1],
    'col3': ['A', 'B', 'C', 'D', 'E']
}

df = pd.DataFrame(data)
df
# Out:
#    col1  col2 col3
# 0     3     5    A
# 1     1     4    B
# 2     2     3    C
# 3     3     2    D
# 4     2     1    E

# %%
df.sort_values(by='col2')
# Out:
#    col1  col2 col3
# 4     2     1    E
# 3     3     2    D
# 2     2     3    C
# 1     1     4    B
# 0     3     5    A

# %%
df.sort_values(by='col2',ascending=False)
# Out:
#    col1  col2 col3
# 0     3     5    A
# 1     1     4    B
# 2     2     3    C
# 3     3     2    D
# 4     2     1    E

# %% [markdown]
# # read and write to files

# %%
import pandas as pd

# Step 1: Create a sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}

df = pd.DataFrame(data)

df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
csv_file = 'sample_data.csv'
df.to_csv(csv_file, index=False)

# %%
read_df = pd.read_csv(csv_file)
read_df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
#pd.read_excel csv (comma seperated file)
#pd.read_excel .xlsx
#pd.read_html .html
